# %%
# !pip install requests \
python-telegram-bot==13.11 \
loguru \
chalice \
boto3 \
wget \
tiktoken \
openai \
langchain \
python-dotenv \
pinecone-client
# Out:
# Requirement already satisfied: requests in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: python-telegram-bot==13.11 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (13.11)
# Requirement already satisfied: loguru in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (0.7.0)
# Requirement already satisfied: chalice in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (1.29.0)
# Requirement already satisfied: boto3 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (1.26.160)
# Requirement already satisfied: wget in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (3.2)
# Requirement already satisfied: tiktoken in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (0.4.0)
# Requirement already satisfied: openai in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (0.27.8)
# Requirement already satisfied: langchain in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (0.0.214)
# Requirement already satisfied: python-dotenv in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: pinecone-client in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: certifi in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from python-telegram-bot==13.11) (2023.5.7)
# Requirement already satisfied: tornado>=6.1 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from python-telegram-bot==13.11) (6.2)
# Requirement already satisfied: APScheduler==3.6.3 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from python-telegram-bot==13.11) (3.6.3)
# Requirement already satisfied: pytz>=2018.6 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from python-telegram-bot==13.11) (2023.3)
# Requirement already satisfied: cachetools==4.2.2 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from python-telegram-bot==13.11) (4.2.2)
# Requirement already satisfied: setuptools>=0.7 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from APScheduler==3.6.3->python-telegram-bot==13.11) (67.8.0)
# Requirement already satisfied: six>=1.4.0 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from APScheduler==3.6.3->python-telegram-bot==13.11) (1.16.0)
# Requirement already satisfied: tzlocal>=1.2 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from APScheduler==3.6.3->python-telegram-bot==13.11) (5.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from requests) (1.26.16)
# Requirement already satisfied: click<9.0,>=7 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from chalice) (8.1.3)
# Requirement already satisfied: botocore<2.0.0,>=1.14.0 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from chalice) (1.29.160)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.0.0 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from chalice) (4.6.3)
# Requirement already satisfied: pip<23.2,>=9 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from chalice) (23.1.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.9.3 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from chalice) (1.0.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.1 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from chalice) (6.0)
# Requirement already satisfied: inquirer<3.0.0,>=2.7.0 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from chalice) (2.10.1)
# Requirement already satisfied: wheel in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from chalice) (0.38.4)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from boto3) (0.6.1)
# Requirement already satisfied: regex>=2022.1.18 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from tiktoken) (2023.6.3)
# Requirement already satisfied: tqdm in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from openai) (4.65.0)
# Requirement already satisfied: aiohttp in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from openai) (3.8.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from langchain) (2.0.17)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from langchain) (0.5.8)
# Requirement already satisfied: langchainplus-sdk>=0.0.17 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from langchain) (0.0.17)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from langchain) (2.8.4)
# Requirement already satisfied: numpy<2,>=1 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from langchain) (1.25.0)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from langchain) (1.2.4)
# Requirement already satisfied: pydantic<2,>=1 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from langchain) (1.10.9)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from langchain) (8.2.2)
# Requirement already satisfied: dnspython>=2.0.0 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from pinecone-client) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from pinecone-client) (2.8.2)
# Requirement already satisfied: attrs>=17.3.0 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: blessed>=1.19.0 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from inquirer<3.0.0,>=2.7.0->chalice) (1.20.0)
# Requirement already satisfied: python-editor>=1.0.4 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from inquirer<3.0.0,>=2.7.0->chalice) (1.0.4)
# Requirement already satisfied: readchar>=3.0.6 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from inquirer<3.0.0,>=2.7.0->chalice) (4.0.5)
# Requirement already satisfied: greenlet!=0.4.17 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.2)
# Requirement already satisfied: wcwidth>=0.1.4 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from blessed>=1.19.0->inquirer<3.0.0,>=2.7.0->chalice) (0.2.6)
# Requirement already satisfied: packaging>=17.0 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (23.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /media/ian/extras/condaenvs/telegram_planner/lib/python3.11/site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (1.0.0)

# %%
# All imports
import os
from dotenv import load_dotenv

# other imports
import tiktoken
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from uuid import uuid4
import pinecone
from tqdm.auto import tqdm
import glob

# %%
# Load environment variables
load_dotenv()
pinecone_key = os.getenv("PINECONE_KEY")
openai_api_key = os.getenv("OPENAI_API_KEY")

# %%
# Load YouTube data
text_files = glob.glob('startup_failures/*.txt')  # adjust the path as needed

# other parts of your code

# Create a function to measure the length of our text in tokens
tokenizer = tiktoken.get_encoding('p50k_base')
def tiktoken_len(text):
    tokens = tokenizer.encode(text, disallowed_special=())
    return len(tokens)

# Initialize a text splitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=400,
    chunk_overlap=20,
    length_function=tiktoken_len,
    separators=["\n\n", "\n", " ", ""]
)
# Different chunking strategies: https://www.pinecone.io/learn/chunking-strategies/

# Initialize the embedding model
model_name = 'text-embedding-ada-002'
embed = OpenAIEmbeddings(
    openai_api_key=openai_api_key
    , model=model_name
    )
# Initialize the Pinecone vector database
index_name = 'youtube-retrieval-augmentation'
pinecone.init(api_key=pinecone_key, environment="asia-southeast1-gcp-free")
# pinecone.create_index(name=index_name, metric='dotproduct', dimension=1536) # Uncomment this if creating for the first time
index = pinecone.GRPCIndex(index_name)

# %%
# Add data to the database
batch_limit = 100
texts = []
metadatas = []

for file in tqdm(text_files):
    with open(file, 'r') as f:
        lines = f.readlines()
        title = lines[0].strip()  # get the title from the first line
        transcript = ' '.join(line.strip() for line in lines[1:])  # get the transcript from the remaining lines
    video_id = os.path.basename(file).replace('.txt', '')
    metadata = {
        'video-id': video_id,
        'title': title
    }
    # print(transcript)
    record_texts = text_splitter.split_text(transcript)
    record_metadatas = [{"chunk": j, "text": text, **metadata} for j, text in enumerate(record_texts)]
    texts.extend(record_texts)
    metadatas.extend(record_metadatas)
    print(f'processing {video_id} with {len(texts)}' )
    if len(texts) >= batch_limit:
        print('len(texts) >= batch_limit')
        ids = [str(uuid4()) for _ in range(len(texts))]
        embeds = embed.embed_documents(texts)
        index.upsert(vectors=zip(ids, embeds, metadatas))
        texts = []
        metadatas = []
    # Insert remaining data
    if texts:  # if there are any remaining texts
        ids = [str(uuid4()) for _ in range(len(texts))]
        embeds = embed.embed_documents(texts)
        index.upsert(vectors=zip(ids, embeds, metadatas))
    print('done processing ' + video_id)
